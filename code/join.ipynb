# %%
import pandas as pd
df1 = pd.read_csv("/Users/jianingcai/Documents/GitHub/dspg23_github_example/data/favorite_food.csv")
df2 = pd.read_csv("/Users/jianingcai/Downloads/jianing_version.csv")

# %%
df2
# Out:
#          name                                   food   Animal         Fact
# 0        alan                                   rice      NaN          NaN
# 1        sara                              ice cream      NaN          NaN
# 2       steve                                 lychee      NaN          NaN
# 3       annie                                noodles      NaN          NaN
# 4     Jianing                                 shrimp  hamster  sleep a lot
# 5   also alan                           fried butter      NaN          NaN
# 6       annie                                noodles      NaN          NaN
# 7     Jianing                                 shrimp  hamster  sleep a lot
# 8   prashanth                                 steak       NaN          NaN
# 9   Nakshatra                                  Pasta      NaN          NaN
# 10    marijke                                 pasta       NaN          NaN
# ...

# %%
df2_notnull = df2.dropna()
df2_notnull
# Out:
#       name    food   Animal         Fact
# 4  Jianing  shrimp  hamster  sleep a lot
# 7  Jianing  shrimp  hamster  sleep a lot

# %%
df1
# Out:
#          name                                   food  Animal              Fact
# 0        alan                                   rice     NaN               NaN
# 1        sara                              ice cream     NaN               NaN
# 2       steve                                 lychee     NaN               NaN
# 3       annie                                noodles     NaN               NaN
# 4     Jianing                                 shrimp     NaN               NaN
# 5   also alan                           fried butter     NaN               NaN
# 6       annie                                noodles     NaN               NaN
# 7     Jianing                                 shrimp     NaN               NaN
# 8   prashanth                                 steak      NaN               NaN
# 9   Nakshatra                                  Pasta  Rabbit  Witty and foodie
# 10    marijke                                 pasta      NaN               NaN
# ...

# %%
df1_tojoin = df1[df1['name']!='Jianing']
df1_tojoin
# Out:
#          name                                   food  Animal              Fact
# 0        alan                                   rice     NaN               NaN
# 1        sara                              ice cream     NaN               NaN
# 2       steve                                 lychee     NaN               NaN
# 3       annie                                noodles     NaN               NaN
# 5   also alan                           fried butter     NaN               NaN
# 6       annie                                noodles     NaN               NaN
# 8   prashanth                                 steak      NaN               NaN
# 9   Nakshatra                                  Pasta  Rabbit  Witty and foodie
# 10    marijke                                 pasta      NaN               NaN
# 11     Treena                              rice also     NaN               NaN
# 12     anjali  ginger snap cookies from trader joes      NaN               NaN
# ...

# %%
final = df1_tojoin.join(df2_notnull.set_index(list(df1_tojoin.columns)), on=list(df1_tojoin.columns), how='outer')
final
# Out:
#          name                                   food   Animal  \
# 0        alan                                   rice      NaN
# 1        sara                              ice cream      NaN
# 2       steve                                 lychee      NaN
# 3       annie                                noodles      NaN
# 6       annie                                noodles      NaN
# 5   also alan                           fried butter      NaN
# 8   prashanth                                 steak       NaN
# 9   Nakshatra                                  Pasta   Rabbit
# 10    marijke                                 pasta       NaN
# 11     Treena                              rice also      NaN
# 12     anjali  ginger snap cookies from trader joes       NaN
# 13    Trinity                                seafood      NaN
# 13    Jianing                                 shrimp  hamster
# 13    Jianing                                 shrimp  hamster
#
#                 Fact
# ...

# %%
final.to_csv("/Users/jianingcai/Documents/GitHub/dspg23_github_example/data/favorite_food.csv", index = False)

# %%
import os as os
print(os.getcwd())
# Out:
# /Users/jianingcai
